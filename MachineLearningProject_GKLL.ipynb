# %% [markdown]
# <a href="https://colab.research.google.com/github/tkdalsdla01-dotcom/MachineLearningProject_GKLL/blob/main/MachineLearningProject_GKLL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# check if this code can go to Git Repository
print("Hello World!")
print("this code should be nice")
# Out:
# Hello World!
# this code should be nice
